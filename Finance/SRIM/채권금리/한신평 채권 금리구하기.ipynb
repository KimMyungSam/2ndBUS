# %% [markdown]
# ##### 한신평 채권 수익률
# 한국신용평가 홈페이지
#
# http://www.kisrating.com/
#
# 신용등급 - 등급별 금리스프레드
#
# https://www.kisrating.com/ratingsStatistics/statics_spread.do

# %%
import pandas as pd
import requests
from io import  StringIO

imsi = '2017.06.05'

url = 'https://www.kisrating.com/ratingsStatistics/statics_spread.do'

data = {
    'startDt':imsi
}

r = requests.post(url, data=data)
dfs = pd.read_html(StringIO(r.text))
df = dfs[0]
df.set_index('구분', inplace=True)

# Respected rate of return
RRR = float(df.loc['BBB-', '5년'])
RRR
# Out:
# 8.59

# %%
 <img src="C:/Finance/SRIM/bbb_5.png">
# Out:
#   File "<ipython-input-3-377eb2abda32>", line 1
#     <img src="C:/Finance/SRIM/bbb_5.png">
#     ^
# SyntaxError: invalid syntax
