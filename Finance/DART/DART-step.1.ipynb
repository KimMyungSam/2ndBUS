# %%
import requests
import re
import json
import pandas as pd
import datetime
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup
from collections import defaultdict
import html5lib


def get_dartOpenApi(code='005930', docs='사업,반기,분기', start_date='20010101', end_date=''):
    
    # 전자공시 오픈API 참조 : http://dart.fss.or.kr/dsap001/guide.do
    
    auth = 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'             # 전자공시 오픈API 인증키
    headers={'Referer':'https://dart.fss.or.kr/dsap001/guide.do'} # 헤더: 실제 인증키를 사용시 사용하지 않아도 된다

    bsn_tps = ''
    dart_docs = []
    
    """ 아래 코드가 python스럽지만, 실행속도 측면에서는 그닥 ...
    if re.search('사업', docs): dart_docs.append('사업보고서')
    if re.search('반기', docs): dart_docs.append('반기보고서')   
    if re.search('분기', docs): dart_docs.append('분기보고서')   
    dart_bsn_tps = {'사업보고서' : 'A001', '반기보고서' : 'A002', '분기보고서' : 'A003'}
    for doc in dart_docs:
        bsn_tps += '&bsn_tp=' + dart_bsn_tps[doc]
    """
    if re.search('사업', docs): dart_docs.append('A001') 
    if re.search('반기', docs): dart_docs.append('A002')
    if re.search('분기', docs): dart_docs.append('A003') 
    if re.search('수시', docs): dart_docs.append('I001')     
    for i in range(0, len(dart_docs)):
        bsn_tps += '&bsn_tp=' + dart_docs[i]

    url_format = ('http://dart.fss.or.kr/api/search.json?auth={auth}&crp_cd={code}' 
                    '&start_dt={start_date}&end_dt={end_date}&%s&page_set=100')
    url = url_format.format(auth=auth, code=code, start_date=start_date, end_date=end_date) % bsn_tps
    r = requests.get(url, headers=headers)
    jo = json.loads(r.text)
    result = json_normalize(jo, 'list')
    
    return result



def get_dartDocUrls(code='005930', docs='사업,반기,분기', start_date='20010101', end_date=''):
    
    df_api = get_dartOpenApi(code, docs, start_date, end_date)
    urls = []
    for i, rcpNo in df_api.iterrows():
        url_format = 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo={}'
        url = url_format.format(rcpNo['rcp_no'])
        urls.append(url)
    
    return urls
   
    
    
def get_dartDocTocUrls(head_url, toc_doc=''):
    
    # 공시보고서 목차(toc:table of contents) url들 리턴
    # toc_doc=목차제목 => 선택한 목차 url 리턴
    
    rcpNo = head_url[-14:]   # head_url = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo={rcpNo:14자리}
    r = requests.get(head_url)

    reg = re.compile('viewDoc\((.*)\);')
    params = []
    matches = reg.findall(r.text)
    for m in matches: 
        params.append(m.replace("'", "").replace(" ", "").split(","))
   
    url_format = ('http://dart.fss.or.kr/report/viewer.do?rcpNo=%s'
                        '&dcmNo=%s&eleId=%s&offset=%s&length=%s&dtd=%s')
    urls = []
    for p in params:
        if rcpNo == p[0]: urls.append(url_format % tuple(p))
            
    if toc_doc != '':
        if   re.search('회사', toc_doc): toc_num = 3
        elif re.search('사업', toc_doc): toc_num = 10
        elif re.search('재무', toc_doc): toc_num = 11
        elif re.search('감사인', toc_doc): toc_num = 18
        elif re.search('이사', toc_doc): toc_num = 19
        elif re.search('이사회', toc_doc): toc_num = 20
        elif re.search('주주', toc_doc): toc_num = 24
        elif re.search('임원', toc_doc): toc_num = 25
        elif re.search('계열회사', toc_doc): toc_num = 28
        elif re.search('이해관계자', toc_doc): toc_num = 29
        elif re.search('그 밖에', toc_doc): toc_num = 30
        elif re.search('전문가', toc_doc): toc_num = 31
        urls = urls[toc_num-1]
        
    return urls



def get_dartDocHtmlTable(doc_url, table_num=0):
    
    r = requests.get(doc_url)
    bs = BeautifulSoup(r.text, 'lxml')
    tables = bs.find_all('table')
    table = tables[table_num-1]
    df = pd.read_html(doc_url)
    
    return df



def get_htmlTable(table):
    
    """ ******************************************************************************************************
     get_htmlTable() : rowspan, colspan된 html table을 pandas dataframe으로 리턴
       - HTML table에 헤더가 없으면 아래 b.만 실행
       - 참조 코드 : https://stackoverflow.com/questions/9978445/parsing-a-table-with-rowspan-and-colspan   
    ==========================================================================================================
     입력인수 table은 html table, <table> ... </table>
     ----------------------------------------------------------------------------------------------------------
     a. 테이블 헤더에서, <theader>...<tr>...<th rowspan="rx" colspan="cy"> th_data </th>...</tr>...</theader>
        a1. rowspan된 개수(rx-1)만큼 아래쪽 행에 th_data 삽입
        a2. colspan된 개수(cy-1)만큼 오른쪽 열에 th_data 삽입
        a3. 테이블 헤더가 존재할 때, 헤더(th)에 rowspan, colspan이 있으면 헤더를 한개 행으로 병합, 상위 항목값은 [ ]로 병합
             -----------------------
            | X |     Y     |   Z   |       --------------------------------------
            |   |-------------------   =>  | X | A[Y] | B[Y] | C[Y] | D[Z] | E[Z] |
            |   | A | B | C | D | E |       --------------------------------------
             -----------------------
    ----------------------------------------------------------------------------------------------------------
     b. 테이블 바디에서, <tbody>...<tr>...<td rowspan="rx" colspan="cy"> td_data </td>...</tr>...</tbody>
        - rowspan된 개수(rx-1)만큼 아래쪽 행에 td_data 삽입
        - colspan된 개수(cy-1)만큼 오른쪽 열에 'NaN' 삽입
    ==========================================================================================================
     기타. 딕셔너리를 리스트로 하면 코딩이 편할 듯 한데, tbody_dct = defaultdict(list), 리스트 딕셔너리 ?
    ****************************************************************************************************** """
    
    thead = defaultdict(lambda : defaultdict(str)) 
    tbody = defaultdict(lambda : defaultdict(str))      
    for trow, tr in enumerate(table.find_all('tr')):
        # run a1. and a2.
        for tcol, th in enumerate(tr.find_all('th')):
            colspan = int(th.get('colspan', 1))             # colspan이 없으면, colspan = 1
            rowspan = int(th.get('rowspan', 1))             # rowspan이 없으면, rowspan = 1
            th_data = th.get_text(strip=True)               # 줄 바꿈('\n') 떼버림(strip)
            while trow in thead and tcol in thead[trow]:
                tcol += 1
            for i in range(trow, trow + rowspan):
                for j in range(tcol, tcol + colspan):       
                    thead[i][j] = th_data                   # rowspan, colspan된 th에 th_data 삽입
        # run b.
        for tcol, td in enumerate(tr.find_all('td')):
            colspan = int(td.get('colspan', 1))             # colspan이 없으면, colspan = 1
            rowspan = int(td.get('rowspan', 1))             # rowspan이 없으면, rowspan = 1
            td_data = td.get_text(strip=True)               # 줄 바꿈('\n') 떼버림(strip)
            while trow in tbody and tcol in tbody[trow]:
                tcol += 1
            for i in range(trow, trow + rowspan):
                tbody[i][tcol] = td_data                    # rowspan된 td에 td_data 삽입
                for j in range(tcol + 1, tcol + colspan):
                    tbody[i][j] = 'NaN'                     # colspan된 td에 NaN 삽입
    
    tbody = list(dict_to_listArray(tbody))                  # tbody(딕셔너리)를 tbdody(리스트 어레이)로 변환 

    # run a3.
    if table.find('thead') != None:  
        th_row = len(thead)-1
        for i in range(th_row-1, -1, -1):
            for j in range(0, len(thead[th_row])):
                if thead[th_row][j] != thead[i][j]:
                    thead[th_row][j] += '[' + thead[i][j] + ']'
        thead = thead[th_row].values()                      # thead(딕셔너리)의 마지막 element를 리스트로 변환
        df = pd.DataFrame(data = tbody, columns = thead)
    else:
        thead_list = []
        df = pd.DataFrame(data = tbody)
    
    return df

        
    
def dict_to_listArray(dict):
    
    for i, row in sorted(dict.items()):
        cols = []
        for j, col in sorted(row.items()):
            cols.append(col)
        yield cols      

        
        
def get_dartSpecificDocUrl(code='005930', doc='사업보고서', doc_date='2016.12'):
      
    date = doc_date.split('.')
    year = date[0]
    month = date[1]
    day = '30'

    # 보고서 3개월 이내 공시, 100일 후로 검색종료 일자 변경
    if month == '1Q' or month == '1q': month = '03'
    if month == '2Q' or month == '2q': month = '06'
    if month == '3Q' or month == '3q': month = '09'
    if month == '4Q' or month == '4q': month = '12'

    date = datetime.date(int(year), int(month), int(day))
    end_date = date + datetime.timedelta(days=100)
    end_date = str(end_date).replace('-','')
    start_date = year + month + day

    df_api = get_dartOpenApi(code, doc, start_date, end_date)

    if   re.search('사업', doc): doc_find = '사업보고서' + '\(' + year + '.' + month + '\)'
    elif re.search('반기', doc): doc_find = '반기보고서' + '\(' + year + '.' + month + '\)'
    elif re.search('분기', doc): doc_find = '분기보고서' + '\(' + year + '.' + month + '\)'

    for ix, rpt_nm in df_api.iterrows():
        if re.search(doc_find, rpt_nm['rpt_nm'].replace(' ','')):
            url_format = 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo={}'
            url = url_format.format(rpt_nm['rcp_no'])
            break
    
    return url



def get_dartSpecificDocHtmlTable(code='005930', doc='사업보고서', doc_date='2016.12', toc_doc='사업', table_num=1):

    doc_url = get_dartSpecificDocUrl(code, doc, doc_date)
    toc_url = get_dartDocTocUrls(doc_url, toc_doc)

    return get_dartDocHtmlTable(toc_url, table_num)

# %%
result = get_dartOpenApi(code='005930', docs='사업보고서', start_date='20100101', end_date='20170101')
result
# Out:
#    crp_cd crp_cls crp_nm flr_nm    rcp_dt          rcp_no rmk  \
# 0  005930       Y   삼성전자   삼성전자  20160330  20160330003536   연
# 1  005930       Y   삼성전자   삼성전자  20150331  20150331002915   연
# 2  005930       Y   삼성전자   삼성전자  20140331  20140331002427   연
# 3  005930       Y   삼성전자   삼성전자  20130401  20130401003031   연
# 4  005930       Y   삼성전자   삼성전자  20120330  20120330002110   연
# 5  005930       Y   삼성전자   삼성전자  20110331  20110331002193   연
# 6  005930       Y   삼성전자   삼성전자  20100331  20100331001680   연
#
#                   rpt_nm
# 0        사업보고서 (2015.12)
# 1        사업보고서 (2014.12)
# 2        사업보고서 (2013.12)
# 3        사업보고서 (2012.12)
# 4  [첨부추가]사업보고서 (2011.12)
# 5  [첨부추가]사업보고서 (2010.12)
# 6  [첨부추가]사업보고서 (2009.12)

# %%
result = get_dartDocUrls(code='005930', docs='사업보고서', start_date='20100101', end_date='20170101')
result[0]
# Out:
# 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20160330003536'

# %%
doc_urls = get_dartDocTocUrls(result[0])
doc_urls
# Out:
# ['http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=1&offset=712&length=4053&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=2&offset=12770&length=410&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=3&offset=13184&length=232563&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=4&offset=13283&length=138879&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=5&offset=152166&length=20381&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=6&offset=172551&length=3614&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=7&offset=176169&length=54264&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=8&offset=230437&length=6828&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=9&offset=237269&length=8464&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=10&offset=245751&length=217728&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=11&offset=463483&length=1307314&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=12&offset=463601&length=20836&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=13&offset=484673&length=108645&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=14&offset=593322&length=497570&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=15&offset=1090896&length=90302&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=16&offset=1181202&length=421680&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=17&offset=1602912&length=167871&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=18&offset=1770801&length=14903&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=19&offset=1785708&length=41882&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=20&offset=1827594&length=51998&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=21&offset=1827707&length=41239&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=22&offset=1868950&length=9975&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=23&offset=1878929&length=649&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=24&offset=1879596&length=58881&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=25&offset=1938481&length=632284&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=26&offset=1938593&length=607535&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=27&offset=2546132&length=24619&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=28&offset=2570769&length=443004&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=29&offset=3013777&length=47335&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=30&offset=3061116&length=13893&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=31&offset=3075013&length=337&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=32&offset=3075105&length=112&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=33&offset=3075221&length=115&dtd=dart3.xsd',
#  'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=1&offset=712&length=4053&dtd=dart3.xsd']

# %%
doc_urls = get_dartDocTocUrls(result[0], toc_doc='사업')
doc_urls
# Out:
# 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003536&dcmNo=5026126&eleId=10&offset=245751&length=217728&dtd=dart3.xsd'

# %%
df = get_dartDocHtmlTable(doc_urls, table_num=11)

#print(df)
df[13]
# Out:
#       부문                                주요 제품                       순매출액  \
# 0  CE 부문  TV, 모니터, 냉장고, 세탁기, 에어컨, 프린터, 의료기기 등                     468954
# 1  IM 부문          HHP, 네트워크시스템, 컴퓨터, 디지털카메라 등                    1035543
# 2   DS부문                               반도체 사업  DRAM, NAND Flash, 모바일AP 등
# 3  DP 사업                      TFT-LCD, OLED 등                     274869
# 4   부문 계                               750261                      37.4%
# 5     기타                                    -                   △248,223
# 6   전체 계                              2006535                     100.0%
#
#        비중 Unnamed: 4
# 0   23.4%        NaN
# 1   51.6%        NaN
# 2  475868      23.7%
# 3   13.7%        NaN
# 4     NaN        NaN
# 5  △12.4%        NaN
# 6     NaN        NaN

# %%
# 위 일련 실행이, 아래 코드와 동일함
df = get_dartSpecificDocHtmlTable(code='005930', doc='사업보고서', doc_date='2016.12', toc_doc='사업', table_num=11)

print(df)
df
# Out:
# [        부문                           주요 제품                 Unnamed: 2
# 0    CE 부문  TV, 모니터, 냉장고, 세탁기, 에어컨, 의료기기 등                        NaN
# 1    IM 부문             HHP, 네트워크시스템, 컴퓨터 등                        NaN
# 2     DS부문                        반도체 사업부문  DRAM, NAND Flash, 모바일AP 등
# 3  DP 사업부문                 TFT-LCD, OLED 등                        NaN,   제 품  2016년  2015년  2014년
# 0  TV  21.6%  21.0%  22.6%,                                                    0
# 0  ※ 2014년, 2015년,2016년 시장점유율은 외부조사기관인 IHS의 세계시장점...,    제 품  2016년  2015년  2014년
# 0  HHP  19.2%  20.7%  22.4%,                                                    0
# 0  ※ 2014년, 2015년, 2016년 시장점유율은 외부조사기관인 Strategy ...,     제 품  2016년  2015년  2014년
# 0  DRAM  48.0%  45.3%  39.6%,                                                    0
# 0  ※ 2014년, 2015년, 2016년 시장점유율은 외부조사기관인 DRAMeXcha...,         제 품  2016년  2015년  2014년
# 0  디스플레이 패널  17.1%  21.1%  20.9%,                                                    0
# 0  ※ 2014년, 2015년, 2016년 시장점유율은 외부조사기관인 IHS의 세계시장...,                0
# 0  (단위 : 백만원, %),        부문       구  분       제48기       제47기       제46기         금액         비중  \
# 0    CE부문       총매출액  109672506      22.8%  120688835      24.5%  124916892
# 1   내부매출액   62627083      22.4%   73793424      25.2%   74733757      25.9%
# 2    순매출액   47045423      23.3%   46895411      23.4%   50183135      24.3%
# 3    영업이익    2638002       9.0%    1254187       4.7%    1184325       4.7%
# 4     총자산   49675022      13.6%   45998007      12.8%   43116374      12.8%
# 5    IM부문       총매출액  211523973      43.9%  222023600      45.0%  236438979
# 6   내부매출액  111221861      39.7%  118469345      40.5%  124674435      43.3%
# 7    순매출액  100302112      49.7%  103554255      51.6%  111764544      54.2%
# 8    영업이익   10807569      37.0%   10142022      38.4%   14562885      58.2%
# 9     총자산  111574049      30.5%   98463323      27.4%   94227108      27.9%
# 10   DS부문        반도체       총매출액   99527926      20.6%   90600806      18.4%
# 11  내부매출액   48370924      17.3%   43014054      14.7%   35328169      12.3%
# 12   순매출액   51157002      25.3%   47586752      23.7%   39729902      19.3%
# 13   영업이익   13595004      46.5%   12787297      48.4%    8776442      35.1%
# 14    총자산  102251069      28.0%   98989253      27.6%   87567196      25.9%
# 15     DP       총매출액   55884739      11.6%   55120243      11.2%   52227615
# 16  내부매출액   28956095      10.3%   27633382       9.4%   26500446       9.2%
# 17   순매출액   26928644      13.3%   27486861      13.7%   25727169      12.5%
# 18   영업이익    2226626       7.6%    2295367       8.7%     660181       2.6%
# 19    총자산   57240065      15.6%   50147263      14.0%   46826533      13.8%
# 20      계       총매출액  159473455      33.1%  149974731      30.4%  131459756
# 21  내부매출액   81325252      29.0%   74948617      25.6%   65669950      22.8%
# 22   순매출액   78148203      38.7%   75026114      37.4%   65789806      31.9%
# 23   영업이익   15850986      54.2%   14887262      56.4%    9430915      37.7%
# 24    총자산  183951625      50.3%  174264841      48.5%  160138321      47.4%
#
#         금액.1   비중.1  금액.2  비중.2
# 0      25.3%    NaN   NaN   NaN
# 1        NaN    NaN   NaN   NaN
# 2        NaN    NaN   NaN   NaN
# 3        NaN    NaN   NaN   NaN
# 4        NaN    NaN   NaN   NaN
# 5      47.9%    NaN   NaN   NaN
# 6        NaN    NaN   NaN   NaN
# 7        NaN    NaN   NaN   NaN
# 8        NaN    NaN   NaN   NaN
# 9        NaN    NaN   NaN   NaN
# 10  75058071  15.2%   NaN   NaN
# 11       NaN    NaN   NaN   NaN
# 12       NaN    NaN   NaN   NaN
# 13       NaN    NaN   NaN   NaN
# 14       NaN    NaN   NaN   NaN
# 15     10.6%    NaN   NaN   NaN
# 16       NaN    NaN   NaN   NaN
# 17       NaN    NaN   NaN   NaN
# 18       NaN    NaN   NaN   NaN
# 19       NaN    NaN   NaN   NaN
# 20     26.6%    NaN   NaN   NaN
# 21       NaN    NaN   NaN   NaN
# 22       NaN    NaN   NaN   NaN
# 23       NaN    NaN   NaN   NaN
# 24       NaN    NaN   NaN   NaN  ,                                                    0
# 0  ※ 순매출액은 본사 및 연결대상 해외법인의 부문간 내부매출을 포함하고 있습니다. [...,               0
# 0  (단위 : 억원, %),       부문                           주요 제품                       순매출액      비중  \
# 0  CE 부문  TV, 모니터, 냉장고, 세탁기, 에어컨, 의료기기 등                     470454   23.3%
# 1  IM 부문             HHP, 네트워크시스템, 컴퓨터 등                    1003021   49.7%
# 2   DS부문                          반도체 사업  DRAM, NAND Flash, 모바일AP 등  511570
# 3  DP 사업                 TFT-LCD, OLED 등                     269286   13.3%
# 4   부문 계                          781482                      38.7%     NaN
# 5     기타                               -                   △236,290  △11.7%
# 6   전체 계                         2018667                     100.0%     NaN
#
#   Unnamed: 4
# 0        NaN
# 1        NaN
# 2      25.3%
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN  ,                           0              1
# 0  ※ 부문간 매출액 포함기준입니다.(연결기준)  [△는 부(-)의 값임],               0
# 0  (단위 : 억원, %),       부문           매입유형             품 목   구체적용도    매입액              비율  \
# 0     CE            원재료        디스플레이 패널   화상신호기  54331           25.1%
# 1    원재료             기타             NaN  162040  74.9%             NaN
# 2   부문 계         216371          100.0%     NaN    NaN             NaN
# 3     IM            원재료  Base Band Chip     CPU  34821           10.3%
# 4    원재료  Camera Module        휴대폰용 카메라   34432  10.2%          삼성전기 등
# 5    원재료  모바일용 디스플레이 패널           화상신호기   19503   5.8%       일진디스플레이 등
# 6    원재료             기타             NaN  249998  73.8%             NaN
# 7   부문 계         338754          100.0%     NaN    NaN             NaN
# 8     DS            원재료          Window    강화유리  21204           10.4%
# 9    원재료            POL             편광판   15942   7.8%  동우화인켐, NITTO 등
# 10   원재료          Glass     디스플레이용 유리기판   14090   6.9%        코닝정밀소재 등
# 11   원재료             기타             NaN  153150  74.9%             NaN
# 12  부문 계         204386          100.0%     NaN    NaN             NaN
# 13    기타            316               -     NaN    NaN             NaN
# 14    총계         759827               -     NaN    NaN             NaN
#
#         주요 매입처
# 0   AUO, BOE 등
# 1          NaN
# 2          NaN
# 3   Qualcomm 등
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8       BIEL 등
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN  ,                                                  0
# 0  ※ 연결 기준으로 작성되었습니다.※ 주요 매입처중 삼성전기는 삼성계열 소속회사입니다.,               0
# 0  (단위 : 천대,천개),       부문   품  목  제48기('16.1.1~12.31)  제47기('15.1.1~12.31)  \
# 0  CE 부문     TV                52308                50450
# 1  IM 부문    HHP               447200               497050
# 2  DS 부문    메모리            415026000            268630000
# 3     DP  10028                 9459                 9185
#
#    제46기('14.1.1~12.31)  수량  수량.1  수량.2
# 0              62990.0 NaN   NaN   NaN
# 1             523750.0 NaN   NaN   NaN
# 2          173506000.0 NaN   NaN   NaN
# 3                  NaN NaN   NaN   NaN  ,                                0
# 0  ※ 생산능력은 글로벌 기준이며, 주요 제품기준입니다.,       부문  품  목  제48기('16.1.1~12.31)  제47기('15.1.1~12.31)  제46기('14.1.1~12.31)  \
# 0  CE 부문    TV                47428                45821              55066.0
# 1  IM 부문   HHP               389838               423058             439520.0
# 2  DS 부문   메모리            415026000            268630000          173506000.0
# 3     DP  8307                 8284                 8252                  NaN
#
#    수량  수량.1  수량.2
# 0 NaN   NaN   NaN
# 1 NaN   NaN   NaN
# 2 NaN   NaN   NaN
# 3 NaN   NaN   NaN  ,                                0
# 0  ※ 생산실적은 글로벌 기준이며, 주요 제품기준입니다.,            0
# 0  (단위 : 천대),       부문  품 목  제48기생산능력 대수\n  제48기실제 생산대수\n    가동률
# 0  CE 부문   TV          52308          47428  90.7%
# 1  IM 부문  HHP         447200         389838  87.2%,            0
# 0  (단위 : 시간),      부문    품 목  제48기가동가능 시간\n 제48기실제 가동시간\n     가동률
# 0  DS부문    메모리          52560         52560  100.0%
# 1    DP  82944          82944        100.0%     NaN,                          지역                          사업장  \
# 0               국내(11개 사업장)                        서초사업장
# 1                     우면사업장       서울특별시 서초구 성촌길 33 (우면동)
# 2                     수원사업장    경기도 수원시 영통구 삼성로 129 (매탄동)
# 3                    구미1사업장      경상북도 구미시 1공단로 244 (공단동)
# 4                    구미2사업장     경상북도 구미시 3공단3로 302 (임수동)
# 5                     기흥사업장    경기도 용인시 기흥구 삼성2로 95 (농서동)
# 6                     온양사업장   충청남도 아산시 배방읍 배방로 158 (북수리)
# 7                     화성사업장        경기도 화성시 삼성전자로 1 (반월동)
# 8                     광주사업장  광주광역시 광산구 하남산단6번로 107 (오선동)
# 9                     천안사업장    충청남도 천안시 서북구 번영로 465(성성동)
# 10                    아산사업장    충청남도 아산시 탕정면 삼성로 181(명암리)
# 11  해외(CE, IM 부문 산하9개 지역총괄)                        북미 총괄
# 12                    구주 총괄                       영국, 런던
# 13                    중국 총괄                       중국, 북경
# 14                   동남아 총괄                     싱가폴, 싱가폴
# 15                   서남아 총괄                      인도, 뉴델리
# 16                   CIS 총괄                    러시아, 모스크바
# 17                    중동 총괄                  아랍에미리트, 두바이
# 18                  아프리카 총괄             남아프리카공화국, 요하네스버그
# 19                   중남미 총괄                    브라질, 상파울로
# 20      해외(DS 부문 산하5개 지역총괄)                        미주 총괄
# 21                    구주 총괄                      독일, 에쉬본
# 22                    중국 총괄                       중국, 상해
# 23                   동남아 총괄                     싱가폴, 싱가폴
# 24                    일본 총괄                       일본, 동경
#
#                            소재지
# 0   서울특별시 서초구 서초대로74길 11 (서초동)
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                     미국, 뉴저지
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                     미국, 산호세
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN  ,             0
# 0  (단위 : 백만원),                  구     분                토지        건물및구축물           기계장치  \
# 0                     기초            기초장부가액       7848432       22453296
# 1                   취득원가           7848432      32850110      147315096
# 2   감가상각누계액 (손상차손누계액 포함)                 -  (10,396,814)  (104,237,217)
# 3                     증감  일반취득 및 자본적지출(*1)         37735        3482228
# 4           사업결합으로 인한 취득                 -             -           4492
# 5                   감가상각                 -   (1,631,089)   (16,814,751)
# 6                  처분/폐기          (28,331)      (26,384)       (80,552)
# 7                     손상                 -       (2,805)      (370,574)
# 8            매각예정자산으로 대체                 -      (11,922)       (20,131)
# 9                 기타(*2)             11843        112502      (263,538)
# 10                    기말            기말장부가액       7869679       24375826
# 11                  취득원가           7869679      36474462      155285378
# 12  감가상각누계액 (손상차손누계액 포함)                 -  (12,098,636)  (116,983,323)
#
#        건설중인자산           기타              계  Unnamed: 7
# 0    43077879     10970052        2127451  86477110.0
# 1    10970052      6303834      205287524         NaN
# 2           -  (4,176,383)  (118,810,414)         NaN
# 3    12769230      8230900         974275  25494368.0
# 4         240         2271           7003         NaN
# 5           -    (866,680)   (19,312,520)         NaN
# 6         (5)     (66,684)      (201,956)         NaN
# 7           -      (1,731)      (375,110)         NaN
# 8     (7,660)     (45,156)       (84,869)         NaN
# 9   (419,541)        27749      (530,985)         NaN
# 10   38302055     18773986        2151495  91473041.0
# 11   18773986      6769149      225172654         NaN
# 12          -  (4,617,654)  (133,699,613)         NaN  ,                                                    0
# 0  ※ 기타 : 환율변동에 의한 증감액 및 관련 정부보조금 차감 효과 등을 포함하고 있...,               0          1
# 0  [부문별 시설투자금액]  (단위 : 억원),   사업부문        구 분          투자기간 대 상 자 산  제48기 투자액  비 고
# 0  반도체  신/증설,보완 등  '16.1~'16.12   건물/설비  131513.0  NaN
# 1   DP  신/증설,보완 등  '16.1~'16.12   건물/설비   98313.0  NaN
# 2  기 타         기타  '16.1~'16.12   건물/설비   25118.0  NaN
# 3  합 계     254944           NaN     NaN       NaN  NaN,            0
# 0  (단위 : 억원),     부  문           매출유형                         품   목  \
# 0  CE 부문  상 품제 품용 역기타매출  TV, 모니터,냉장고, 세탁기,에어컨, 의료기기 등
# 1  IM 부문  상 품제 품용 역기타매출             HHP,네트워크시스템,컴퓨터 등
# 2   DS부문         반도체 사업                 상 품제 품용 역기타매출
# 3  DP 사업  상 품제 품용 역기타매출                TFT-LCD,OLED 등
# 4   부문 계         781482                        750261
# 5    기 타           기타매출                             -
# 6    합 계        2018667                       2006535
#
#                제48기(2016년) 제47기(2015년) 제46기(2014년) Unnamed: 6  Unnamed: 7
# 0                        계      470454      468954     501831         NaN
# 1                        계     1003021     1035543    1117645         NaN
# 2  DRAM,NAND Flash,모바일AP 등           계      511570     475868    397299.0
# 3                        계      269286      274869     257272         NaN
# 4                   657898         NaN         NaN        NaN         NaN
# 5                        계    △236,290    △248,223   △215,314         NaN
# 6                  2062060         NaN         NaN        NaN         NaN  ,                            0              1
# 0  ※ 부문간 매출액 포함 기준입니다.(연결기준)  [Δ는 부(-)의 값임],            0
# 0  (단위 : 억원),   구      분  제48기(2016년)  제47기(2015년)  제46기(2014년)
# 0     영상기기       287241       292194       324486
# 1       무선       977494      1005117      1074149
# 2   MEMORY       378594       342917       293244
# 3       DP       269286       274869       257272,                            0
# 0  ※ 부문간 매출액 포함 기준입니다.(연결기준),            0
# 0  (단위 : 억원),     구      분  제48기(2016년)  제47기(2015년)  제46기(2014년)
# 0        제상품      2006326      1988452      2036716
# 1  용역 및 기타매출        12341        18083        25344
# 2          계      2018667      2006535      2062060,                               0
# 0  ※ 기타매출은 로열티수익 등으로 구성되어 있습니다.,            0
# 0  (단위 : 억원),      구      분  제48기(2016년)  제47기(2015년)\n  제46기(2014년)
# 0          국내       140656         145908       153247
# 1          미주       426448         425042       433940
# 2          유럽       170850         173583       208982
# 3  아시아 및 아프리카       281021         291473       298140
# 4          중국       320497         316044       283946
# 5           계      1339472        1352050      1378255,                          판매자          판매경로  소비자
# 0                    생산자(공장)           대리점  소비자
# 1  유통업체(양판점,할인점,백화점,홈쇼핑,인터넷)           NaN  NaN
# 2                        대리점  농협, 구판장, 계열점  NaN
# 3     통신사업자(SKT, KT, LG유플러스)           NaN  NaN
# 4                       직접판매           NaN  NaN,            판매자      판매경로       소비자 Unnamed: 3
# 0         생산법인      판매법인  Retailer        소비자
# 1       Dealer  Retailer       NaN        NaN
# 2  Distributor    Dealer  Retailer        NaN
# 3        통신사업자       NaN       NaN        NaN
# 4         물류법인      판매법인  Retailer        NaN
# 5       Dealer  Retailer       NaN        NaN
# 6  Distributor    Dealer  Retailer        NaN
# 7         직접판매       NaN       NaN        NaN,    경 로   도매   소매  특직판  기타
# 0  비 중  28%  26%  41%  5%,               0
# 0  ※ Global 기준임,   구   분                 판매경로                              대금회수조건  \
# 0    전속                  대리점  - 약정여신수금(현금,30일여신) (담보 100%내 여신적용)
# 1  유통업체  양판점,할인점,백화점,홈쇼핑,인터넷                              개별계약조건
# 2   특직판              일반기업체 등                              개별계약조건
#
#              부대비용 비용분담
# 0  - 사안별 상호 협의하에 일부 분담
# 1  - 사안별 상호 협의하에 일부 분담
# 2                  없 음  ,          구   분          판매경로  대금회수조건            부대비용 비용분담
# 0     Retailer           소매점  개별계약조건  - 사안별 상호 협의하에 일부 분담
# 1       Dealer   양판점,할인점,백화점  개별계약조건  - 사안별 상호 협의하에 일부 분담
# 2  Distributor  현지 거래선 직판 영업  개별계약조건  - 사안별 상호 협의하에 일부 분담
# 3          B2B       일반기업체 등  개별계약조건                  없 음,            0
# 0  (단위: 백만원),   구   분       당기말        전기말    환율 상승시     환율 하락시  환율 상승시.1  환율 하락시.1
# 0   USD    222149  (222,149)    143266  (143,266)       NaN       NaN
# 1   EUR    138084  (138,084)     19626   (19,626)       NaN       NaN
# 2   JPY  (61,294)      61294  (15,120)      15120       NaN       NaN,                 0
# 0  [()는 부(-)의 값임],            0
# 0  (단위: 백만원),   구   분      당기말       전기말   이자율 상승시   이자율 하락시  이자율 상승시.1  이자율 하락시.1
# 0  금융자산    64803  (64,803)     81962  (81,962)        NaN        NaN
# 1  금융부채  (9,123)      9123  (22,314)     22314        NaN        NaN
# 2   순효과    55680  (55,680)     59648  (59,648)        NaN        NaN,                 0
# 0  [()는 부(-)의 값임],            0
# 0  (단위: 백만원),    구  분    3개월 이내    ~ 6개월    ~ 1년   1 ~ 5년  5년 초과
# 0  금융부채  40918912  1588798  150744  4346200  50073,    구  분    3개월 이내   ~ 6개월     ~ 1년   1 ~ 5년   5년 초과
# 0  금융부채  32275387  412196  1331166  3057099  476432,   구   분        당기말        전기말
# 0   부 채   69211291   63119716
# 1   자 본  192963033  179059805
# 2  부채비율      35.9%      35.3%,            0
# 0  (단위: 백만원),              구   분          당기말      전기말         장부금액     공정가치  장부금액.1  공정가치.1
# 0             금융자산          NaN      NaN          NaN      NaN     NaN     NaN
# 1         현금및현금성자산   32111442.0     (*1)   22636744.0     (*1)     NaN     NaN
# 2           단기금융상품   52432411.0     (*1)   44228800.0     (*1)     NaN     NaN
# 3       단기매도가능금융자산    3638460.0  3638460    4627530.0  4627530     NaN     NaN
# 4             매출채권   24279211.0     (*1)   25168026.0     (*1)     NaN     NaN
# 5   장기매도가능금융자산(*2)    6804276.0  5826507    8332480.0  8225687     NaN     NaN
# 6           기타(*3)    3459863.0   919071    3546434.0  1070839     NaN     NaN
# 7              소 계  122725663.0      NaN  108540014.0      NaN     NaN     NaN
# 8             금융부채          NaN      NaN          NaN      NaN     NaN     NaN
# 9             매입채무    6485039.0     (*1)    6187291.0     (*1)     NaN     NaN
# 10           단기차입금   12746789.0     (*1)   11155425.0     (*1)     NaN     NaN
# 11            미지급금   10225271.0     (*1)    7625490.0     (*1)     NaN     NaN
# 12         유동성장기부채    1232817.0     (*1)     221548.0     (*1)     NaN     NaN
# 13              사채      58542.0    76129    1230448.0  1261783     NaN     NaN
# 14           장기차입금    1244238.0  1225455     266542.0   242603     NaN     NaN
# 15          장기미지급금    3009659.0  3022821    2719674.0  2581985     NaN     NaN
# 16          기타(*3)   11942469.0    74697    7947398.0    38829     NaN     NaN
# 17             소 계   46944824.0      NaN   37353816.0      NaN     NaN     NaN,            0
# 0  (단위: 백만원),       구     분      당기말  Level 1  Level 2    Level 3   계
# 0     (1) 자 산      NaN      NaN      NaN        NaN NaN
# 1  단기매도가능금융자산        -  3638460        -  3638460.0 NaN
# 2  장기매도가능금융자산  2362235        -  3464272  5826507.0 NaN
# 3          기타        -   919071        -   919071.0 NaN
# 4     (2) 부 채      NaN      NaN      NaN        NaN NaN
# 5          사채        -    76129        -    76129.0 NaN
# 6       장기차입금        -  1225455        -  1225455.0 NaN
# 7      장기미지급금        -  2680119   342702  3022821.0 NaN
# 8          기타        -    74697        -    74697.0 NaN,       구     분      전기말    Level 1  Level 2    Level 3   계
# 0     (1) 자 산      NaN        NaN      NaN        NaN NaN
# 1  단기매도가능금융자산        -  4627530.0        -  4627530.0 NaN
# 2  장기매도가능금융자산  4674753    78189.0  3472745  8225687.0 NaN
# 3          기타        -  1055240.0    15599  1070839.0 NaN
# 4     (2) 부 채      NaN        NaN      NaN        NaN NaN
# 5          사채        -  1261783.0        -  1261783.0 NaN
# 6       장기차입금        -   242603.0        -   242603.0 NaN
# 7      장기미지급금        -  2269247.0   312738  2581985.0 NaN
# 8          기타        -    38829.0        -    38829.0 NaN,            0
# 0  (단위: 백만원),                          구  분                   공정가치   가치평가기법 Level 3 투입변수  \
# 0                  장기매도가능금융자산                    NaN      NaN          NaN
# 1               말타니(구 태원전기산업)                  16270  현금흐름할인법        영구성장율
# 2                    가중평균자본비용     7.45%~9.45%(8.45%)      NaN          NaN
# 3                      삼성벤처투자                   7515  현금흐름할인법        영구성장율
# 4                    가중평균자본비용  21.31%~23.31%(22.31%)      NaN          NaN
# 5  Corning Incorporated 전환우선주                3440487     삼항모형       위험 할인율
# 6                      가격 변동성    27.8%~33.8%(30.80%)      NaN          NaN
# 7                      장기미지급금                    NaN      NaN          NaN
# 8                     조건부금융부채                 342702  현금흐름할인법          할인율
#
#         투입변수 범위(가중평균)
# 0                 NaN
# 1    -1.00%~1.00%(0%)
# 2                 NaN
# 3    -1.00%~1.00%(0%)
# 4                 NaN
# 5  5.74%~7.74%(6.74%)
# 6                 NaN
# 7                 NaN
# 8  3.81%~4.65%(4.23%)  ,                 0
# 0  [()는 부(-)의 값임],            0
# 0  (단위: 백만원),               금융자산         당기         전기
# 0             기초잔액    3488344    3548095
# 1               매입          -     119297
# 2             매도 등   (14,805)   (55,986)
# 3    당기손익으로 인식된 손익      (795)       3530
# 4  기타포괄손익으로 인식된 손익     695631  (304,012)
# 5               기타  (704,103)     177420
# 6             기말잔액    3464272    3488344,                 0
# 0  [()는 부(-)의 값임],            0
# 0  (단위: 백만원),             금융부채      당기      전기
# 0           기초잔액  312738       -
# 1  당기손익으로 인식된 손익   29964  312738
# 2           기말잔액  342702  312738,            0
# 0  (단위: 백만원),           구     분 유리한 변동  불리한 변동     당기손익         자본  당기손익.1  자본.1
# 0  장기매도가능금융자산(*1)      -  194732        -  (227,857)     NaN   NaN
# 1      장기미지급금(*2)   1920    1920  (1,932)    (1,932)     NaN   NaN
# 2               계   1920  196652  (1,932)  (229,789)     NaN   NaN,                 0
# 0  [()는 부(-)의 값임],             0
# 0  (단위 : 백만원),   Unnamed: 0 자산  부채 평가이익  평가손실
# 0     풋-옵션 등  -   -    -   794
# 1          계  -   -    -   794,                           0
# 0  ※ 옵션가치 산정은 블랙숄즈 모형 등을 사용,             0
# 0  (단위 : 백만원),       구분     취득원가     공정가치     평가이익 평가손실
# 0  전환우선주  2434320  3440487  1006167    -,   Unnamed: 0     자산     부채   평가이익   평가손실
# 0       통화선도  63014  74678  52389  66645
# 1          계  63014  74678  52389  66645,        계약 상대방                             항  목          내   용
# 0         에릭슨                            계약 유형    상호 특허 사용 계약
# 1   체결시기 및 기간                       2014.01.25            NaN
# 2     목적 및 내용         상호 특허 라이센스를 통한 사업 자유도 확보            NaN
# 3     기타 주요내용                                -            NaN
# 4          구글                            계약 유형    상호 특허 사용 계약
# 5   체결시기 및 기간                  2014.01.25 / 영구            NaN
# 6     목적 및 내용         상호 특허 라이센스를 통한 사업 자유도 확보            NaN
# 7     기타 주요내용  영구 라이센스 계약(향후 10년간 출원될 특허까지 포함)            NaN
# 8         시스코                            계약 유형    상호 특허 사용 계약
# 9   체결시기 및 기간                       2014.01.23            NaN
# 10    목적 및 내용         상호 특허 라이센스를 통한 사업 자유도 확보            NaN
# 11    기타 주요내용                                -            NaN
# 12  글로벌 파운드리즈                            계약 유형  공정 기술 라이센스 계약
# 13  체결시기 및 기간                       2014.02.28            NaN
# 14    목적 및 내용                 14nm 공정의 고객기반 확대            NaN
# 15    기타 주요내용                                -            NaN
# 16      인터디지털                            계약 유형       특허 사용 계약
# 17  체결시기 및 기간                       2014.06.03            NaN
# 18    목적 및 내용            특허 라이센스를 통한 사업 자유도 확보            NaN
# 19    기타 주요내용                                -            NaN
# 20      Sharp                            계약 유형     상호 특허 사용계약
# 21  체결시기 및 기간                       2015.01.01            NaN
# 22    목적 및 내용         상호 특허 라이센스를 통한 사업 자유도 확보            NaN
# 23    기타 주요내용                                -            NaN
# 24    마이크로소프트                            계약 유형        분쟁종료 합의
# 25  체결시기 및 기간                                -            NaN
# 26    목적 및 내용              로열티 지급에 관한 분쟁 종료 목적            NaN
# 27    기타 주요내용                                -            NaN
# 28        노키아                            계약 유형       특허 사용 계약
# 29  체결시기 및 기간                       2016.07.12            NaN
# 30    목적 및 내용            특허 라이센스를 통한 사업 자유도 확보            NaN
# 31    기타 주요내용                                -            NaN
# 32         HP                            계약 유형      프린팅 사업 매각
# 33  체결시기 및 기간                       2016.09.12            NaN
# 34    목적 및 내용                핵심역량 강화를 통한 사업고도화            NaN
# 35    기타 주요내용                 계약금액 : USD 10.5억            NaN
# 36     Harman                            계약 유형          지분 인수
# 37  체결시기 및 기간                       2016.11.14            NaN
# 38    목적 및 내용               지분 인수를 통한 사업 역량 강화            NaN
# 39    기타 주요내용                 계약금액 : USD 80.2억            NaN,           0           1
# 0  [연구개발비용]  (단위 : 백만원),                               과     목           제48기       제47기         제46기  \
# 0                            연구개발비용 계       14792343   14848754     15325507
# 1                                회계처리  개발비 자산화(무형자산)  (680,962)  (1,143,059)
# 2                           연구개발비(비용)       14111381   13705695     14385506
# 3  연구개발비 / 매출액 비율[연구개발비용 계÷당기매출액×100]           7.3%       7.4%         7.4%
#
#   Unnamed: 4
# 0        NaN
# 1  (940,001)
# 2        NaN
# 3        NaN  ,                                                   0
# 0  ※ 연결기준이며, 한국채택국제회계기준에 따라 작성되었습니다. [()는 부(-)의 값임],           0
# 0  연구개발 조직도,                                        연구과제  \
# 0                              스마트카드 신제품 개발
# 1                   고해상도 저소비전력 Tablet 제품 기술
# 2               Server향 20나노 4GB DDR3 D램 양산
# 3                      ISOCELL 이미지센서 신제품 개발
# 4                  HMP 솔루션 적용 모바일 AP 신제품 개발
# 5                             UHD TV HU9000
# 6               PC향 2세대 V-NAND기반 1TB SSD 양산
# 7                      ISOCELL 이미지센서 신제품 개발
# 8                             모바일 AP 신제품 개발
# 9                       UHD TV (UN105S9WAF)
# 10                                  LFD QMD
# 11              PC/서버향 32단 3비트 3D V-NAND 양산
# 12              Bendable TV Nov (UN78S9BAF)
# 13            Mobile향 20나노 8Gb LPDDR4 D램 양산
# 14                            모바일 AP 신제품 출시
# 15                               NFC 신제품 출시
# 16               Mobile向 10나노급 128GB UFS 양산
# 17                                SUHD TV출시
# 18    PC向 10나노급 NAND기반 512GB M.2 NVMe SSD양산
# 19                      HAV(WAA) WAM5500/ZA
# 20                        CMOS 이미지센서 신제품 출시
# 21         SSD向 3세대(48단) 256Gb 3D V-NAND 양산
# 22    Mobile向20나노 D램기반 12Gb LPDDR4 모바일 D램양산
# 23                                  LFD OHD
# 24  서버向 20나노 D램기반 128GB 3D TSV DDR4 RDIMM양산
# 25                        CAC 시스템에어컨AC9000K
# 26                       DVM 시스템에어컨 AM7500K
# 27                           바이오 프로세서통합칩 양산
# 28            HPC向 20나노 D램기반 4GB HBM2 D램 양산
# 29                                  LFD DCE
# 30                                   LM TC2
# 31                        DVM 시스템에어컨AM9100K
# 32          모바일向 3세대(48단) V낸드기반 256GB UFS양산
# 33     서버向 3세대(48단) V낸드기반 15.36TB SAS SSD양산
# 34          PC/서버向 10나노급(1x) 8Gb DDR4 D램 양산
# 35                                  LM CF59
# 36                          FDR 냉장고RF9500KF
# 37                                엑시노스 8 옥타
# 38                                   엑시노스 7
# 39                                모바일 이미지센서
# 40                                  LFD OHE
# 41                                  LM CF39
# 42                         SUHD TV (KS9000)
# 43                  SUHD TV (KS7500/KS7000)
# 44                   UHD TV (KU6500/KU6400)
# 45                          UHD TV (KU6000)
# 46                   FHD TV (K5100) (K4100)
# 47                            HD-TV (HE690)
# 48                                엑시노스 7 쿼드
# 49                           식기세척기(DW9900M)
# 50                      RAC 가정용에어컨(AR5500M)
#
#                                           연구결과 및 기대효과  \
# 0   □ 플래시 메모리 내장 (e-flash) NFC 출시  - 업계 유일 45나노 e-...
# 1   □ 고해상도 Tablet 패널 양산□ 투과율향상에 의한 Tablet 제품의 저소비전...
# 2   □ 세계 최초 초미세 20나노 4GB DDR3 D램 양산  - 독자개발 '고집적/초...
# 3   □ 1600만화소 ISOCELL 이미지센서 신제품 출시  - 어두운 공간에서도 선명...
# 4   □ Exynos 5 Octa (5422) 신제품 출시  - HMP 솔루션 적용으로 ...
# 5   □ 완벽한 몰입감을 주는 Ultimate Curved UHD TV  - 인체공학적 ...
# 6   □ 세계 최초 2세대 3D V낸드기반 1TB SSD 양산  - 2세대 V낸드로 '3...
# 7   □ 1300만화소 적층형 ISOCELL 이미지센서 개발  - 적층형 구조로 칩 크기...
# 8   □ Exynos 5 Octa (5430) 신제품 출시  - 20나노 저전력 HKMG...
# 9   □ Product Concept  - Wide Curved(21:9) 105" UH...
# 10  □ Premium UHD Line Up 도입  - 고해상도 UHD급 LFD 라인업 ...
# 11  □ 세계 최초 3비트(bit) 3D V낸드기반 1TB SSD 양산  - 3비트 V낸...
# 12  □ 세계 최초 Bendable UHD TV  - 당사 Tech Leadership ...
# 13  □ 세계 최초 초미세 20나노8Gb LPDDR4 D램 양산  - 독자개발 '고집적/...
# 14  □ 업계 최초 14나노 핀펫 공정 기반 모바일 AP  - 14나노 공정은 20나노 ...
# 15  □ RF 성능 향상된 4세대 NFC 솔루션  - 3세대 제품 比 카드모드 2배, 리...
# 16  □ 세계 최초 차세대 모바일용 메모리 128GB UFS 양산  - 메모리카드의 12...
# 17  □ Curved SUHD TV : 궁극의 몰입감 제공  ※ S : 압도적인(Spec...
# 18  □ 세계 최초 차세대 PC용 512GB M.2 NVMe SSD 양산  - SATA ...
# 19  □ Ambient Audio  차별화된 음질 및 감성적 디자인으로 신규 카테고리 제...
# 20  □ 업계 최초 1.0um 1600만 화소 모바일 이미지센서  - 아이소셀 기술로 1...
# 21  □ 세계 최초 3세대(48단) 256Gb 3D V낸드 양산  - 128Gb 낸드보다...
# 22  □ 세계 최초 차세대 모바일용 12Gb LPDDR4 D램 양산  - PC D램보다 ...
# 23  □ Product Concept  - Outdoor Signage의 Digital화...
# 24  □ 세계 최초 차세대 서버용 128GB 3D TSV RDIMM양산  - 3차원 TS...
# 25  □ 제품 특성  - 세계최초 Bladeless 360 카세트 개발  - 원형 기류로...
# 26  □ 제품 특성  - 동일 Size 업계 최대 용량  - Compact Size & ...
# 27  □ 업계 최초 바이오 프로세서 통합칩 양산  - AEF 外 MCU, DSP, eFl...
# 28  □ 세계 최초 차세대 HPC용 4GB HBM2 D램 양산  - 시스템속도 3.6배 ...
# 29  □ 사양 및 효과  - DBE 모델의 기구, 패널 공용하여 Slim 대응과 NT14...
# 30  □ 사양 및 효과  - CPU 사양 Upgrade를 통해 경쟁력 제고  ※ 1.0G...
# 31  □ 제품 특성  - 고효율 Inverter Chiller 시장 진입  - 효율(구주...
# 32  □ 세계 최초 차세대 스마트폰용 256GB UFS 양산  - uSD카드 대비 9배,...
# 33  □ 세계 최초 차세대 서버용 15.36TB SAS SSD 양산  - 256Gb V낸...
# 34  □ 세계 최초 차세대 10나노급 8Gb DDR4 D램 양산  - 20나노대비 생산성...
# 35  □ 사양 및 효과  - 회로 : 1 D-Sub/1HDMI/1DP 의 Triple I...
# 36  □ 제품 특성 - IOT시대에 새로운 사용경험 제안으로 스마트가전시장 선도 및 신규...
# 37  □ 14나노 2세대 공정 기반 Premium 모바일 SOC  - 성능과 절전효과 더...
# 38  □ 업계 최초 14나노 기반 보급형 모바일 SOC  - 14나노 파생공정 적용  -...
# 39  □ 듀얼 픽셀 1,200만 화소 모바일 이미지센서  - 모든 화소에서 고속으로 위상...
# 40  □ 사양 및 효과  - 기존 Outdoor 사양 유지  - 110℃ TNI Pane...
# 41  □ 사양 및 효과  - 16:9 세계 최고 곡률의 1800R 적용  - 라운드 형태...
# 42  □ Curved SUHD TV □ Design : Dignity, Bezel-les...
# 43  □ Curved SUHD TV □ Design : Triumph, Bezel-les...
# 44  □ UHD Curved TV □ Design : Metal Design, Bolt-...
# 45  □ UHD Flat TV □ Design : Minimalism 디자인, V-Sha...
# 46  □ FHD Flat TV □ Design : Louvre Design, Semi E...
# 47  □ Product Concept  - Market Segment별 특화 제품 및 솔...
# 48  □ 커넥티비티 통합 모바일 SOC  - 28나노 前 세대 제품 比 성능 70%, 전...
# 49  □ 제품 특성  - 2세대 WaterWall  - Zone booster 기능강화 ...
# 50  □ 제품 특성  - 친환경(Low-GWP) R32 냉매 도입을 통한 시장 환경 변화...
#
#                         제품 등에 반영된 경우  제품 등의 명칭 및 반영내용
# 0             □ 지역 : 글로벌 □ 출시 : '14.1월 □ 명칭 : S3FWRN5
# 1                              □ 지역: 글로벌 □ 출시: '14.2월
# 2         □ 지역 : 글로벌 □ 출시 : '14.2월 □ 명칭 : 4GB DDR3 D램
# 3              □ 지역 : 글로벌 □ 출시 : '14.3월 □ 명칭 : S5K2P2
# 4   □ 지역 : 글로벌 □ 출시 : '14.1월/3월 □ 명칭 : Exynos5250/...
# 5             □ 지역 : 글로벌 □ 출시 : '14.3월 □ 인치 : 55"/65"
# 6      □ 지역 : 글로벌 □ 출시 : '14.5월 □ 명칭 : 1TB V-NAND SSD
# 7              □ 지역 : 글로벌 □ 출시 : '14.6월 □ 명칭 : S5K3M2
# 8         □ 지역 : 글로벌 □ 출시 : '14.6월 □ 명칭 : Exynos 5430
# 9                □ 지역 : 글로벌 □ 출시 : '14.7월 □ 인치 : 105"
# 10                 □ 지역: 글로벌 □ 출시 : '14.8월 □ 인치 : 85"
# 11  □ 지역 : 글로벌 □ 출시 : '14.10월 □ 명칭 : 128Gb 3bit 3D...
# 12                □ 지역 : 국내 □ 출시 : '14.11월 □ 인치 : 78"
# 13     □ 지역 : 글로벌 □ 출시 : '14.12월 □ 명칭 : 8Gb LPDDR4 D램
# 14      □ 지역 : 글로벌 □ 출시 : '15.1월 □ 명칭 : Exynos 7 Octa
# 15           □ 지역 : 글로벌 □ 출시 : '15.1월 □ 명칭 : S3FWRN5P
# 16  □ 지역 : 글로벌 □ 출시 : '15.2월 □ 명칭 : 128GB UFS (내장 ...
# 17         □ 지역 : 글로벌 □ 출시 : '15.3월 □ 인치: 65"/78"/88"
# 18  □ 지역 : 글로벌 □ 출시 : '15.4월 □ 명칭 : 512GB M.2 NVMe...
# 19                            □ 지역 : 미주 □ 출시 : '15.8월
# 20             □ 지역 : 글로벌 □ 출시 : '15.7월 □ 명칭 : S5K3P3
# 21  □ 지역 : 글로벌 □ 출시 : '15.8월 □ 명칭 : 256Gb 3D V낸드  ...
# 22  □ 지역 : 글로벌 □ 출시 : '15.9월 □ 명칭 : 12Gb LPDDR4  모...
# 23           □ 지역 : 글로벌 □ 출시 : '15.10월 □ 인치 : 46"/55"
# 24  □ 지역 : 글로벌 □ 출시 : '15.11월 □ 명칭 : 128GB 3D TSV ...
# 25                          □ 지역 : 글로벌 □ 출시 : '15.12월
# 26                          □ 지역 : 글로벌 □ 출시 : '15.12월
# 27           □ 지역 : 글로벌 □ 출시 : '15.12월 □ 명칭 : S3FBP5A
# 28  □ 지역 : 글로벌 □ 출시 : '16.1월 □ 명칭 : 4GB HBM2 D램 (2...
# 29        □ 지역 : 글로벌 □ 출시 : '16.1월 □ 인치 :32/40/48/55"
# 30            □ 지역 : 글로벌 □ 출시 : '16.1월 □ 인치 : 22"/24"
# 31                           □ 지역 : 글로벌 □ 출시 : '16.1월
# 32  □ 지역 : 글로벌 □ 출시 : '16.2월 □ 명칭 : 256GB UFS  (3세...
# 33  □ 지역 : 글로벌 □ 출시 : '16.2월 □ 명칭 : 15.36TB SAS SS...
# 34  □ 지역 : 글로벌 □ 출시 : '16.2월 □ 명칭 : 8Gb DDR4 D램 (1...
# 35                □ 지역 : 글로벌 □ 출시 : '16.2월 □ 인치 : 27"
# 36                           □ 지역 : 글로벌 □ 출시 : '16.2월
# 37            □ 지역 : 글로벌 □ 출시 : '16.3월 □ 명칭 : S5E8990
# 38            □ 지역 : 글로벌 □ 출시 : '16.3월 □ 명칭 : S5E7870
# 39             □ 지역 : 글로벌 □ 출시 : '16.3월 □ 명칭 : S5K2L1
# 40                □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 24"
# 41            □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 24"/27"
# 42        □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 49"/55"/65"
# 43    □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 43"/49"/55"/65"
# 44  □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 40"/43"/49"/55...
# 45  □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 40"/43"/50"/55...
# 46  □ 지역 : 글로벌 □ 출시 : '16.4월 □ 인치 : 32"/40"/43"/49...
# 47  □ 지역 : 글로벌 □ 출시 : '16.8월 □ 인치 : 22"/24"/28"/32...
# 48            □ 지역 : 글로벌 □ 출시 : '16.8월 □ 명칭 : S5E7570
# 49                           □ 지역 : 북미 □ 출시 : '16.12월
# 50                          □ 지역 : 글로벌 □ 출시 : '16.12월  ,                              0         1
# 0  < 국가별 등록 건수(2016년末 기준, 누적)>  (단위 : 件),    국가     한국     미국     유럽     중국    일본  기타국가
# 0  건수  27471  43806  16744  10242  6770  8813,                 0         1
# 0  < 연도별 특허등록 건수>  (단위 : 件),   특허등록  \n'16년\n  \n'15년\n  \n'14년\n  \n'13년\n  '12년  '11년  '10년  '09년
# 0   한국      3452      2984      3970      2762  2013  1610  1612  1485
# 1   미국      5518      5072      4952      4676  5081  4894  4551  3611,                  구분    2016년    2015년    2014년
# 0  온실가스(단위 : tCO2e)  6885300  6729419  6775019
# 1      에너지(단위 : TJ)   107740   111166   101386,                                                    0
# 0  ※ 대상 : 국내 제조사업장, 사옥, 당사 소유 건물, 임차 건물 등※ 온실가스 사...]
# [        부문                           주요 제품                 Unnamed: 2
#  0    CE 부문  TV, 모니터, 냉장고, 세탁기, 에어컨, 의료기기 등                        NaN
#  1    IM 부문             HHP, 네트워크시스템, 컴퓨터 등                        NaN
#  2     DS부문                        반도체 사업부문  DRAM, NAND Flash, 모바일AP 등
#  3  DP 사업부문                 TFT-LCD, OLED 등                        NaN,
#    제 품  2016년  2015년  2014년
#  0  TV  21.6%  21.0%  22.6%,
#                                                     0
#  0  ※ 2014년, 2015년,2016년 시장점유율은 외부조사기관인 IHS의 세계시장점...,
#     제 품  2016년  2015년  2014년
#  0  HHP  19.2%  20.7%  22.4%,
#                                                     0
#  0  ※ 2014년, 2015년, 2016년 시장점유율은 외부조사기관인 Strategy ...,
#      제 품  2016년  2015년  2014년
#  0  DRAM  48.0%  45.3%  39.6%,
#                                                     0
#  0  ※ 2014년, 2015년, 2016년 시장점유율은 외부조사기관인 DRAMeXcha...,
#          제 품  2016년  2015년  2014년
#  0  디스플레이 패널  17.1%  21.1%  20.9%,
#                                                     0
#  0  ※ 2014년, 2015년, 2016년 시장점유율은 외부조사기관인 IHS의 세계시장...,
#                 0
#  0  (단위 : 백만원, %),
#         부문       구  분       제48기       제47기       제46기         금액         비중  \
#  0    CE부문       총매출액  109672506      22.8%  120688835      24.5%  124916892
#  1   내부매출액   62627083      22.4%   73793424      25.2%   74733757      25.9%
#  2    순매출액   47045423      23.3%   46895411      23.4%   50183135      24.3%
#  3    영업이익    2638002       9.0%    1254187       4.7%    1184325       4.7%
#  4     총자산   49675022      13.6%   45998007      12.8%   43116374      12.8%
#  5    IM부문       총매출액  211523973      43.9%  222023600      45.0%  236438979
#  6   내부매출액  111221861      39.7%  118469345      40.5%  124674435      43.3%
#  7    순매출액  100302112      49.7%  103554255      51.6%  111764544      54.2%
#  8    영업이익   10807569      37.0%   10142022      38.4%   14562885      58.2%
#  9     총자산  111574049      30.5%   98463323      27.4%   94227108      27.9%
#  10   DS부문        반도체       총매출액   99527926      20.6%   90600806      18.4%
#  11  내부매출액   48370924      17.3%   43014054      14.7%   35328169      12.3%
#  12   순매출액   51157002      25.3%   47586752      23.7%   39729902      19.3%
#  13   영업이익   13595004      46.5%   12787297      48.4%    8776442      35.1%
#  14    총자산  102251069      28.0%   98989253      27.6%   87567196      25.9%
#  15     DP       총매출액   55884739      11.6%   55120243      11.2%   52227615
#  16  내부매출액   28956095      10.3%   27633382       9.4%   26500446       9.2%
#  17   순매출액   26928644      13.3%   27486861      13.7%   25727169      12.5%
#  18   영업이익    2226626       7.6%    2295367       8.7%     660181       2.6%
#  19    총자산   57240065      15.6%   50147263      14.0%   46826533      13.8%
#  20      계       총매출액  159473455      33.1%  149974731      30.4%  131459756
#  21  내부매출액   81325252      29.0%   74948617      25.6%   65669950      22.8%
#  22   순매출액   78148203      38.7%   75026114      37.4%   65789806      31.9%
#  23   영업이익   15850986      54.2%   14887262      56.4%    9430915      37.7%
#  24    총자산  183951625      50.3%  174264841      48.5%  160138321      47.4%
#
#          금액.1   비중.1  금액.2  비중.2
#  0      25.3%    NaN   NaN   NaN
#  1        NaN    NaN   NaN   NaN
#  2        NaN    NaN   NaN   NaN
#  3        NaN    NaN   NaN   NaN
#  4        NaN    NaN   NaN   NaN
#  5      47.9%    NaN   NaN   NaN
#  6        NaN    NaN   NaN   NaN
#  7        NaN    NaN   NaN   NaN
#  8        NaN    NaN   NaN   NaN
#  9        NaN    NaN   NaN   NaN
#  10  75058071  15.2%   NaN   NaN
#  11       NaN    NaN   NaN   NaN
#  12       NaN    NaN   NaN   NaN
#  13       NaN    NaN   NaN   NaN
#  14       NaN    NaN   NaN   NaN
#  15     10.6%    NaN   NaN   NaN
#  16       NaN    NaN   NaN   NaN
#  17       NaN    NaN   NaN   NaN
#  18       NaN    NaN   NaN   NaN
#  19       NaN    NaN   NaN   NaN
#  20     26.6%    NaN   NaN   NaN
#  21       NaN    NaN   NaN   NaN
#  22       NaN    NaN   NaN   NaN
#  23       NaN    NaN   NaN   NaN
#  24       NaN    NaN   NaN   NaN  ,
#                                                     0
#  0  ※ 순매출액은 본사 및 연결대상 해외법인의 부문간 내부매출을 포함하고 있습니다. [...,
#                0
#  0  (단위 : 억원, %),
#        부문                           주요 제품                       순매출액      비중  \
#  0  CE 부문  TV, 모니터, 냉장고, 세탁기, 에어컨, 의료기기 등                     470454   23.3%
#  1  IM 부문             HHP, 네트워크시스템, 컴퓨터 등                    1003021   49.7%
#  2   DS부문                          반도체 사업  DRAM, NAND Flash, 모바일AP 등  511570
#  3  DP 사업                 TFT-LCD, OLED 등                     269286   13.3%
#  4   부문 계                          781482                      38.7%     NaN
#  5     기타                               -                   △236,290  △11.7%
#  6   전체 계                         2018667                     100.0%     NaN
#
#    Unnamed: 4
#  0        NaN
#  1        NaN
#  2      25.3%
#  3        NaN
#  4        NaN
#  5        NaN
#  6        NaN  ,
#                            0              1
#  0  ※ 부문간 매출액 포함기준입니다.(연결기준)  [△는 부(-)의 값임],
#                0
#  0  (단위 : 억원, %),
#        부문           매입유형             품 목   구체적용도    매입액              비율  \
#  0     CE            원재료        디스플레이 패널   화상신호기  54331           25.1%
#  1    원재료             기타             NaN  162040  74.9%             NaN
#  2   부문 계         216371          100.0%     NaN    NaN             NaN
#  3     IM            원재료  Base Band Chip     CPU  34821           10.3%
#  4    원재료  Camera Module        휴대폰용 카메라   34432  10.2%          삼성전기 등
#  5    원재료  모바일용 디스플레이 패널           화상신호기   19503   5.8%       일진디스플레이 등
#  6    원재료             기타             NaN  249998  73.8%             NaN
#  7   부문 계         338754          100.0%     NaN    NaN             NaN
#  8     DS            원재료          Window    강화유리  21204           10.4%
#  9    원재료            POL             편광판   15942   7.8%  동우화인켐, NITTO 등
#  10   원재료          Glass     디스플레이용 유리기판   14090   6.9%        코닝정밀소재 등
#  11   원재료             기타             NaN  153150  74.9%             NaN
#  12  부문 계         204386          100.0%     NaN    NaN             NaN
#  13    기타            316               -     NaN    NaN             NaN
#  14    총계         759827               -     NaN    NaN             NaN
#
#          주요 매입처
#  0   AUO, BOE 등
#  1          NaN
#  2          NaN
#  3   Qualcomm 등
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8       BIEL 등
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN  ,
#                                                   0
#  0  ※ 연결 기준으로 작성되었습니다.※ 주요 매입처중 삼성전기는 삼성계열 소속회사입니다.,
#                0
#  0  (단위 : 천대,천개),
#        부문   품  목  제48기('16.1.1~12.31)  제47기('15.1.1~12.31)  \
#  0  CE 부문     TV                52308                50450
#  1  IM 부문    HHP               447200               497050
#  2  DS 부문    메모리            415026000            268630000
#  3     DP  10028                 9459                 9185
#
#     제46기('14.1.1~12.31)  수량  수량.1  수량.2
#  0              62990.0 NaN   NaN   NaN
#  1             523750.0 NaN   NaN   NaN
#  2          173506000.0 NaN   NaN   NaN
#  3                  NaN NaN   NaN   NaN  ,
#                                 0
#  0  ※ 생산능력은 글로벌 기준이며, 주요 제품기준입니다.,
#        부문  품  목  제48기('16.1.1~12.31)  제47기('15.1.1~12.31)  제46기('14.1.1~12.31)  \
#  0  CE 부문    TV                47428                45821              55066.0
#  1  IM 부문   HHP               389838               423058             439520.0
#  2  DS 부문   메모리            415026000            268630000          173506000.0
#  3     DP  8307                 8284                 8252                  NaN
#
#     수량  수량.1  수량.2
#  0 NaN   NaN   NaN
#  1 NaN   NaN   NaN
#  2 NaN   NaN   NaN
#  3 NaN   NaN   NaN  ,
#                                 0
#  0  ※ 생산실적은 글로벌 기준이며, 주요 제품기준입니다.,
#             0
#  0  (단위 : 천대),
#        부문  품 목  제48기생산능력 대수\n  제48기실제 생산대수\n    가동률
#  0  CE 부문   TV          52308          47428  90.7%
#  1  IM 부문  HHP         447200         389838  87.2%,
#             0
#  0  (단위 : 시간),
#       부문    품 목  제48기가동가능 시간\n 제48기실제 가동시간\n     가동률
#  0  DS부문    메모리          52560         52560  100.0%
#  1    DP  82944          82944        100.0%     NaN,
#                           지역                          사업장  \
#  0               국내(11개 사업장)                        서초사업장
#  1                     우면사업장       서울특별시 서초구 성촌길 33 (우면동)
#  2                     수원사업장    경기도 수원시 영통구 삼성로 129 (매탄동)
#  3                    구미1사업장      경상북도 구미시 1공단로 244 (공단동)
#  4                    구미2사업장     경상북도 구미시 3공단3로 302 (임수동)
#  5                     기흥사업장    경기도 용인시 기흥구 삼성2로 95 (농서동)
#  6                     온양사업장   충청남도 아산시 배방읍 배방로 158 (북수리)
#  7                     화성사업장        경기도 화성시 삼성전자로 1 (반월동)
#  8                     광주사업장  광주광역시 광산구 하남산단6번로 107 (오선동)
#  9                     천안사업장    충청남도 천안시 서북구 번영로 465(성성동)
#  10                    아산사업장    충청남도 아산시 탕정면 삼성로 181(명암리)
#  11  해외(CE, IM 부문 산하9개 지역총괄)                        북미 총괄
#  12                    구주 총괄                       영국, 런던
#  13                    중국 총괄                       중국, 북경
#  14                   동남아 총괄                     싱가폴, 싱가폴
#  15                   서남아 총괄                      인도, 뉴델리
#  16                   CIS 총괄                    러시아, 모스크바
#  17                    중동 총괄                  아랍에미리트, 두바이
#  18                  아프리카 총괄             남아프리카공화국, 요하네스버그
#  19                   중남미 총괄                    브라질, 상파울로
#  20      해외(DS 부문 산하5개 지역총괄)                        미주 총괄
#  21                    구주 총괄                      독일, 에쉬본
#  22                    중국 총괄                       중국, 상해
#  23                   동남아 총괄                     싱가폴, 싱가폴
#  24                    일본 총괄                       일본, 동경
#
#                             소재지
#  0   서울특별시 서초구 서초대로74길 11 (서초동)
#  1                          NaN
#  2                          NaN
#  3                          NaN
#  4                          NaN
#  5                          NaN
#  6                          NaN
#  7                          NaN
#  8                          NaN
#  9                          NaN
#  10                         NaN
#  11                     미국, 뉴저지
#  12                         NaN
#  13                         NaN
#  14                         NaN
#  15                         NaN
#  16                         NaN
#  17                         NaN
#  18                         NaN
#  19                         NaN
#  20                     미국, 산호세
#  21                         NaN
#  22                         NaN
#  23                         NaN
#  24                         NaN  ,
#              0
#  0  (단위 : 백만원),
#                   구     분                토지        건물및구축물           기계장치  \
#  0                     기초            기초장부가액       7848432       22453296
#  1                   취득원가           7848432      32850110      147315096
#  2   감가상각누계액 (손상차손누계액 포함)                 -  (10,396,814)  (104,237,217)
#  3                     증감  일반취득 및 자본적지출(*1)         37735        3482228
#  4           사업결합으로 인한 취득                 -             -           4492
#  5                   감가상각                 -   (1,631,089)   (16,814,751)
#  6                  처분/폐기          (28,331)      (26,384)       (80,552)
#  7                     손상                 -       (2,805)      (370,574)
#  8            매각예정자산으로 대체                 -      (11,922)       (20,131)
#  9                 기타(*2)             11843        112502      (263,538)
#  10                    기말            기말장부가액       7869679       24375826
#  11                  취득원가           7869679      36474462      155285378
#  12  감가상각누계액 (손상차손누계액 포함)                 -  (12,098,636)  (116,983,323)
#
#         건설중인자산           기타              계  Unnamed: 7
#  0    43077879     10970052        2127451  86477110.0
#  1    10970052      6303834      205287524         NaN
#  2           -  (4,176,383)  (118,810,414)         NaN
#  3    12769230      8230900         974275  25494368.0
#  4         240         2271           7003         NaN
#  5           -    (866,680)   (19,312,520)         NaN
#  6         (5)     (66,684)      (201,956)         NaN
#  7           -      (1,731)      (375,110)         NaN
#  8     (7,660)     (45,156)       (84,869)         NaN
#  9   (419,541)        27749      (530,985)         NaN
#  10   38302055     18773986        2151495  91473041.0
#  11   18773986      6769149      225172654         NaN
#  12          -  (4,617,654)  (133,699,613)         NaN  ,
#                                                     0
#  0  ※ 기타 : 환율변동에 의한 증감액 및 관련 정부보조금 차감 효과 등을 포함하고 있...,
#                0          1
#  0  [부문별 시설투자금액]  (단위 : 억원),
#    사업부문        구 분          투자기간 대 상 자 산  제48기 투자액  비 고
#  0  반도체  신/증설,보완 등  '16.1~'16.12   건물/설비  131513.0  NaN
#  1   DP  신/증설,보완 등  '16.1~'16.12   건물/설비   98313.0  NaN
#  2  기 타         기타  '16.1~'16.12   건물/설비   25118.0  NaN
#  3  합 계     254944           NaN     NaN       NaN  NaN,
#             0
# ...
#  1  단기매도가능금융자산        -  3638460        -  3638460.0 NaN
#  2  장기매도가능금융자산  2362235        -  3464272  5826507.0 NaN
#  3          기타        -   919071        -   919071.0 NaN
#  4     (2) 부 채      NaN      NaN      NaN        NaN NaN
#  5          사채        -    76129        -    76129.0 NaN
#  6       장기차입금        -  1225455        -  1225455.0 NaN
#  7      장기미지급금        -  2680119   342702  3022821.0 NaN
#  8          기타        -    74697        -    74697.0 NaN,
#        구     분      전기말    Level 1  Level 2    Level 3   계
#  0     (1) 자 산      NaN        NaN      NaN        NaN NaN
#  1  단기매도가능금융자산        -  4627530.0        -  4627530.0 NaN
#  2  장기매도가능금융자산  4674753    78189.0  3472745  8225687.0 NaN
#  3          기타        -  1055240.0    15599  1070839.0 NaN
#  4     (2) 부 채      NaN        NaN      NaN        NaN NaN
#  5          사채        -  1261783.0        -  1261783.0 NaN
#  6       장기차입금        -   242603.0        -   242603.0 NaN
#  7      장기미지급금        -  2269247.0   312738  2581985.0 NaN
#  8          기타        -    38829.0        -    38829.0 NaN,
#             0
#  0  (단위: 백만원),
#                           구  분                   공정가치   가치평가기법 Level 3 투입변수  \
#  0                  장기매도가능금융자산                    NaN      NaN          NaN
#  1               말타니(구 태원전기산업)                  16270  현금흐름할인법        영구성장율
#  2                    가중평균자본비용     7.45%~9.45%(8.45%)      NaN          NaN
#  3                      삼성벤처투자                   7515  현금흐름할인법        영구성장율
#  4                    가중평균자본비용  21.31%~23.31%(22.31%)      NaN          NaN
#  5  Corning Incorporated 전환우선주                3440487     삼항모형       위험 할인율
#  6                      가격 변동성    27.8%~33.8%(30.80%)      NaN          NaN
#  7                      장기미지급금                    NaN      NaN          NaN
#  8                     조건부금융부채                 342702  현금흐름할인법          할인율
#
#          투입변수 범위(가중평균)
#  0                 NaN
#  1    -1.00%~1.00%(0%)
#  2                 NaN
#  3    -1.00%~1.00%(0%)
#  4                 NaN
#  5  5.74%~7.74%(6.74%)
#  6                 NaN
#  7                 NaN
#  8  3.81%~4.65%(4.23%)  ,
#                  0
#  0  [()는 부(-)의 값임],
#             0
#  0  (단위: 백만원),
#                금융자산         당기         전기
#  0             기초잔액    3488344    3548095
#  1               매입          -     119297
#  2             매도 등   (14,805)   (55,986)
#  3    당기손익으로 인식된 손익      (795)       3530
#  4  기타포괄손익으로 인식된 손익     695631  (304,012)
#  5               기타  (704,103)     177420
#  6             기말잔액    3464272    3488344,
#                  0
#  0  [()는 부(-)의 값임],
#             0
#  0  (단위: 백만원),
#              금융부채      당기      전기
#  0           기초잔액  312738       -
#  1  당기손익으로 인식된 손익   29964  312738
#  2           기말잔액  342702  312738,
#             0
#  0  (단위: 백만원),
#            구     분 유리한 변동  불리한 변동     당기손익         자본  당기손익.1  자본.1
#  0  장기매도가능금융자산(*1)      -  194732        -  (227,857)     NaN   NaN
#  1      장기미지급금(*2)   1920    1920  (1,932)    (1,932)     NaN   NaN
#  2               계   1920  196652  (1,932)  (229,789)     NaN   NaN,
#                  0
#  0  [()는 부(-)의 값임],
#              0
#  0  (단위 : 백만원),
#    Unnamed: 0 자산  부채 평가이익  평가손실
#  0     풋-옵션 등  -   -    -   794
#  1          계  -   -    -   794,
#                            0
#  0  ※ 옵션가치 산정은 블랙숄즈 모형 등을 사용,
#              0
#  0  (단위 : 백만원),
#        구분     취득원가     공정가치     평가이익 평가손실
#  0  전환우선주  2434320  3440487  1006167    -,
#    Unnamed: 0     자산     부채   평가이익   평가손실
#  0       통화선도  63014  74678  52389  66645
#  1          계  63014  74678  52389  66645,
#         계약 상대방                             항  목          내   용
#  0         에릭슨                            계약 유형    상호 특허 사용 계약
#  1   체결시기 및 기간                       2014.01.25            NaN
#  2     목적 및 내용         상호 특허 라이센스를 통한 사업 자유도 확보            NaN
#  3     기타 주요내용                                -            NaN
#  4          구글                            계약 유형    상호 특허 사용 계약
#  5   체결시기 및 기간                  2014.01.25 / 영구            NaN
#  6     목적 및 내용         상호 특허 라이센스를 통한 사업 자유도 확보            NaN
#  7     기타 주요내용  영구 라이센스 계약(향후 10년간 출원될 특허까지 포함)            NaN
#  8         시스코                            계약 유형    상호 특허 사용 계약
#  9   체결시기 및 기간                       2014.01.23            NaN
#  10    목적 및 내용         상호 특허 라이센스를 통한 사업 자유도 확보            NaN
#  11    기타 주요내용                                -            NaN
#  12  글로벌 파운드리즈                            계약 유형  공정 기술 라이센스 계약
#  13  체결시기 및 기간                       2014.02.28            NaN
#  14    목적 및 내용                 14nm 공정의 고객기반 확대            NaN
#  15    기타 주요내용                                -            NaN
#  16      인터디지털                            계약 유형       특허 사용 계약
#  17  체결시기 및 기간                       2014.06.03            NaN
#  18    목적 및 내용            특허 라이센스를 통한 사업 자유도 확보            NaN
#  19    기타 주요내용                                -            NaN
#  20      Sharp                            계약 유형     상호 특허 사용계약
#  21  체결시기 및 기간                       2015.01.01            NaN
#  22    목적 및 내용         상호 특허 라이센스를 통한 사업 자유도 확보            NaN
#  23    기타 주요내용                                -            NaN
#  24    마이크로소프트                            계약 유형        분쟁종료 합의
#  25  체결시기 및 기간                                -            NaN
#  26    목적 및 내용              로열티 지급에 관한 분쟁 종료 목적            NaN
#  27    기타 주요내용                                -            NaN
#  28        노키아                            계약 유형       특허 사용 계약
#  29  체결시기 및 기간                       2016.07.12            NaN
#  30    목적 및 내용            특허 라이센스를 통한 사업 자유도 확보            NaN
#  31    기타 주요내용                                -            NaN
#  32         HP                            계약 유형      프린팅 사업 매각
#  33  체결시기 및 기간                       2016.09.12            NaN
#  34    목적 및 내용                핵심역량 강화를 통한 사업고도화            NaN
#  35    기타 주요내용                 계약금액 : USD 10.5억            NaN
#  36     Harman                            계약 유형          지분 인수
#  37  체결시기 및 기간                       2016.11.14            NaN
#  38    목적 및 내용               지분 인수를 통한 사업 역량 강화            NaN
#  39    기타 주요내용                 계약금액 : USD 80.2억            NaN,
#            0           1
#  0  [연구개발비용]  (단위 : 백만원),
#                                과     목           제48기       제47기         제46기  \
#  0                            연구개발비용 계       14792343   14848754     15325507
#  1                                회계처리  개발비 자산화(무형자산)  (680,962)  (1,143,059)
#  2                           연구개발비(비용)       14111381   13705695     14385506
#  3  연구개발비 / 매출액 비율[연구개발비용 계÷당기매출액×100]           7.3%       7.4%         7.4%
#
#    Unnamed: 4
#  0        NaN
#  1  (940,001)
#  2        NaN
#  3        NaN  ,
#                                                    0
#  0  ※ 연결기준이며, 한국채택국제회계기준에 따라 작성되었습니다. [()는 부(-)의 값임],
#            0
#  0  연구개발 조직도,
#                                         연구과제  \
#  0                              스마트카드 신제품 개발
#  1                   고해상도 저소비전력 Tablet 제품 기술
#  2               Server향 20나노 4GB DDR3 D램 양산
#  3                      ISOCELL 이미지센서 신제품 개발
#  4                  HMP 솔루션 적용 모바일 AP 신제품 개발
#  5                             UHD TV HU9000
#  6               PC향 2세대 V-NAND기반 1TB SSD 양산
#  7                      ISOCELL 이미지센서 신제품 개발
#  8                             모바일 AP 신제품 개발
#  9                       UHD TV (UN105S9WAF)
#  10                                  LFD QMD
#  11              PC/서버향 32단 3비트 3D V-NAND 양산
#  12              Bendable TV Nov (UN78S9BAF)
#  13            Mobile향 20나노 8Gb LPDDR4 D램 양산
#  14                            모바일 AP 신제품 출시
#  15                               NFC 신제품 출시
#  16               Mobile向 10나노급 128GB UFS 양산
#  17                                SUHD TV출시
#  18    PC向 10나노급 NAND기반 512GB M.2 NVMe SSD양산
#  19                      HAV(WAA) WAM5500/ZA
#  20                        CMOS 이미지센서 신제품 출시
#  21         SSD向 3세대(48단) 256Gb 3D V-NAND 양산
#  22    Mobile向20나노 D램기반 12Gb LPDDR4 모바일 D램양산
#  23                                  LFD OHD
#  24  서버向 20나노 D램기반 128GB 3D TSV DDR4 RDIMM양산
#  25                        CAC 시스템에어컨AC9000K
#  26                       DVM 시스템에어컨 AM7500K
#  27                           바이오 프로세서통합칩 양산
#  28            HPC向 20나노 D램기반 4GB HBM2 D램 양산
#  29                                  LFD DCE
#  30                                   LM TC2
#  31                        DVM 시스템에어컨AM9100K
#  32          모바일向 3세대(48단) V낸드기반 256GB UFS양산
#  33     서버向 3세대(48단) V낸드기반 15.36TB SAS SSD양산
#  34          PC/서버向 10나노급(1x) 8Gb DDR4 D램 양산
#  35                                  LM CF59
#  36                          FDR 냉장고RF9500KF
#  37                                엑시노스 8 옥타
#  38                                   엑시노스 7
#  39                                모바일 이미지센서
#  40                                  LFD OHE
#  41                                  LM CF39
#  42                         SUHD TV (KS9000)
#  43                  SUHD TV (KS7500/KS7000)
#  44                   UHD TV (KU6500/KU6400)
#  45                          UHD TV (KU6000)
#  46                   FHD TV (K5100) (K4100)
#  47                            HD-TV (HE690)
#  48                                엑시노스 7 쿼드
#  49                           식기세척기(DW9900M)
#  50                      RAC 가정용에어컨(AR5500M)
#
#                                            연구결과 및 기대효과  \
#  0   □ 플래시 메모리 내장 (e-flash) NFC 출시  - 업계 유일 45나노 e-...
#  1   □ 고해상도 Tablet 패널 양산□ 투과율향상에 의한 Tablet 제품의 저소비전...
#  2   □ 세계 최초 초미세 20나노 4GB DDR3 D램 양산  - 독자개발 '고집적/초...
#  3   □ 1600만화소 ISOCELL 이미지센서 신제품 출시  - 어두운 공간에서도 선명...
#  4   □ Exynos 5 Octa (5422) 신제품 출시  - HMP 솔루션 적용으로 ...
#  5   □ 완벽한 몰입감을 주는 Ultimate Curved UHD TV  - 인체공학적 ...
#  6   □ 세계 최초 2세대 3D V낸드기반 1TB SSD 양산  - 2세대 V낸드로 '3...
#  7   □ 1300만화소 적층형 ISOCELL 이미지센서 개발  - 적층형 구조로 칩 크기...
#  8   □ Exynos 5 Octa (5430) 신제품 출시  - 20나노 저전력 HKMG...
#  9   □ Product Concept  - Wide Curved(21:9) 105" UH...
#  10  □ Premium UHD Line Up 도입  - 고해상도 UHD급 LFD 라인업 ...
#  11  □ 세계 최초 3비트(bit) 3D V낸드기반 1TB SSD 양산  - 3비트 V낸...
#  12  □ 세계 최초 Bendable UHD TV  - 당사 Tech Leadership ...
#  13  □ 세계 최초 초미세 20나노8Gb LPDDR4 D램 양산  - 독자개발 '고집적/...
#  14  □ 업계 최초 14나노 핀펫 공정 기반 모바일 AP  - 14나노 공정은 20나노 ...
#  15  □ RF 성능 향상된 4세대 NFC 솔루션  - 3세대 제품 比 카드모드 2배, 리...
#  16  □ 세계 최초 차세대 모바일용 메모리 128GB UFS 양산  - 메모리카드의 12...
#  17  □ Curved SUHD TV : 궁극의 몰입감 제공  ※ S : 압도적인(Spec...
#  18  □ 세계 최초 차세대 PC용 512GB M.2 NVMe SSD 양산  - SATA ...
#  19  □ Ambient Audio  차별화된 음질 및 감성적 디자인으로 신규 카테고리 제...
#  20  □ 업계 최초 1.0um 1600만 화소 모바일 이미지센서  - 아이소셀 기술로 1...
#  21  □ 세계 최초 3세대(48단) 256Gb 3D V낸드 양산  - 128Gb 낸드보다...
#  22  □ 세계 최초 차세대 모바일용 12Gb LPDDR4 D램 양산  - PC D램보다 ...
#  23  □ Product Concept  - Outdoor Signage의 Digital화...
#  24  □ 세계 최초 차세대 서버용 128GB 3D TSV RDIMM양산  - 3차원 TS...
#  25  □ 제품 특성  - 세계최초 Bladeless 360 카세트 개발  - 원형 기류로...
#  26  □ 제품 특성  - 동일 Size 업계 최대 용량  - Compact Size & ...
#  27  □ 업계 최초 바이오 프로세서 통합칩 양산  - AEF 外 MCU, DSP, eFl...
#  28  □ 세계 최초 차세대 HPC용 4GB HBM2 D램 양산  - 시스템속도 3.6배 ...
#  29  □ 사양 및 효과  - DBE 모델의 기구, 패널 공용하여 Slim 대응과 NT14...
#  30  □ 사양 및 효과  - CPU 사양 Upgrade를 통해 경쟁력 제고  ※ 1.0G...
#  31  □ 제품 특성  - 고효율 Inverter Chiller 시장 진입  - 효율(구주...
#  32  □ 세계 최초 차세대 스마트폰용 256GB UFS 양산  - uSD카드 대비 9배,...
#  33  □ 세계 최초 차세대 서버용 15.36TB SAS SSD 양산  - 256Gb V낸...
#  34  □ 세계 최초 차세대 10나노급 8Gb DDR4 D램 양산  - 20나노대비 생산성...
#  35  □ 사양 및 효과  - 회로 : 1 D-Sub/1HDMI/1DP 의 Triple I...
#  36  □ 제품 특성 - IOT시대에 새로운 사용경험 제안으로 스마트가전시장 선도 및 신규...
#  37  □ 14나노 2세대 공정 기반 Premium 모바일 SOC  - 성능과 절전효과 더...
#  38  □ 업계 최초 14나노 기반 보급형 모바일 SOC  - 14나노 파생공정 적용  -...
#  39  □ 듀얼 픽셀 1,200만 화소 모바일 이미지센서  - 모든 화소에서 고속으로 위상...
#  40  □ 사양 및 효과  - 기존 Outdoor 사양 유지  - 110℃ TNI Pane...
#  41  □ 사양 및 효과  - 16:9 세계 최고 곡률의 1800R 적용  - 라운드 형태...
#  42  □ Curved SUHD TV □ Design : Dignity, Bezel-les...
#  43  □ Curved SUHD TV □ Design : Triumph, Bezel-les...
#  44  □ UHD Curved TV □ Design : Metal Design, Bolt-...
#  45  □ UHD Flat TV □ Design : Minimalism 디자인, V-Sha...
#  46  □ FHD Flat TV □ Design : Louvre Design, Semi E...
#  47  □ Product Concept  - Market Segment별 특화 제품 및 솔...
#  48  □ 커넥티비티 통합 모바일 SOC  - 28나노 前 세대 제품 比 성능 70%, 전...
#  49  □ 제품 특성  - 2세대 WaterWall  - Zone booster 기능강화 ...
#  50  □ 제품 특성  - 친환경(Low-GWP) R32 냉매 도입을 통한 시장 환경 변화...
#
#                          제품 등에 반영된 경우  제품 등의 명칭 및 반영내용
#  0             □ 지역 : 글로벌 □ 출시 : '14.1월 □ 명칭 : S3FWRN5
#  1                              □ 지역: 글로벌 □ 출시: '14.2월
#  2         □ 지역 : 글로벌 □ 출시 : '14.2월 □ 명칭 : 4GB DDR3 D램
#  3              □ 지역 : 글로벌 □ 출시 : '14.3월 □ 명칭 : S5K2P2
#  4   □ 지역 : 글로벌 □ 출시 : '14.1월/3월 □ 명칭 : Exynos5250/...
#  5             □ 지역 : 글로벌 □ 출시 : '14.3월 □ 인치 : 55"/65"
#  6      □ 지역 : 글로벌 □ 출시 : '14.5월 □ 명칭 : 1TB V-NAND SSD
#  7              □ 지역 : 글로벌 □ 출시 : '14.6월 □ 명칭 : S5K3M2
#  8         □ 지역 : 글로벌 □ 출시 : '14.6월 □ 명칭 : Exynos 5430
#  9                □ 지역 : 글로벌 □ 출시 : '14.7월 □ 인치 : 105"
#  10                 □ 지역: 글로벌 □ 출시 : '14.8월 □ 인치 : 85"
#  11  □ 지역 : 글로벌 □ 출시 : '14.10월 □ 명칭 : 128Gb 3bit 3D...
#  12                □ 지역 : 국내 □ 출시 : '14.11월 □ 인치 : 78"
#  13     □ 지역 : 글로벌 □ 출시 : '14.12월 □ 명칭 : 8Gb LPDDR4 D램
#  14      □ 지역 : 글로벌 □ 출시 : '15.1월 □ 명칭 : Exynos 7 Octa
#  15           □ 지역 : 글로벌 □ 출시 : '15.1월 □ 명칭 : S3FWRN5P
#  16  □ 지역 : 글로벌 □ 출시 : '15.2월 □ 명칭 : 128GB UFS (내장 ...
#  17         □ 지역 : 글로벌 □ 출시 : '15.3월 □ 인치: 65"/78"/88"
#  18  □ 지역 : 글로벌 □ 출시 : '15.4월 □ 명칭 : 512GB M.2 NVMe...
#  19                            □ 지역 : 미주 □ 출시 : '15.8월
#  20             □ 지역 : 글로벌 □ 출시 : '15.7월 □ 명칭 : S5K3P3
#  21  □ 지역 : 글로벌 □ 출시 : '15.8월 □ 명칭 : 256Gb 3D V낸드  ...
#  22  □ 지역 : 글로벌 □ 출시 : '15.9월 □ 명칭 : 12Gb LPDDR4  모...
#  23           □ 지역 : 글로벌 □ 출시 : '15.10월 □ 인치 : 46"/55"
#  24  □ 지역 : 글로벌 □ 출시 : '15.11월 □ 명칭 : 128GB 3D TSV ...
#  25                          □ 지역 : 글로벌 □ 출시 : '15.12월
#  26                          □ 지역 : 글로벌 □ 출시 : '15.12월
#  27           □ 지역 : 글로벌 □ 출시 : '15.12월 □ 명칭 : S3FBP5A
#  28  □ 지역 : 글로벌 □ 출시 : '16.1월 □ 명칭 : 4GB HBM2 D램 (2...
#  29        □ 지역 : 글로벌 □ 출시 : '16.1월 □ 인치 :32/40/48/55"
#  30            □ 지역 : 글로벌 □ 출시 : '16.1월 □ 인치 : 22"/24"
#  31                           □ 지역 : 글로벌 □ 출시 : '16.1월
#  32  □ 지역 : 글로벌 □ 출시 : '16.2월 □ 명칭 : 256GB UFS  (3세...
#  33  □ 지역 : 글로벌 □ 출시 : '16.2월 □ 명칭 : 15.36TB SAS SS...
#  34  □ 지역 : 글로벌 □ 출시 : '16.2월 □ 명칭 : 8Gb DDR4 D램 (1...
#  35                □ 지역 : 글로벌 □ 출시 : '16.2월 □ 인치 : 27"
#  36                           □ 지역 : 글로벌 □ 출시 : '16.2월
#  37            □ 지역 : 글로벌 □ 출시 : '16.3월 □ 명칭 : S5E8990
#  38            □ 지역 : 글로벌 □ 출시 : '16.3월 □ 명칭 : S5E7870
#  39             □ 지역 : 글로벌 □ 출시 : '16.3월 □ 명칭 : S5K2L1
#  40                □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 24"
#  41            □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 24"/27"
#  42        □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 49"/55"/65"
#  43    □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 43"/49"/55"/65"
#  44  □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 40"/43"/49"/55...
#  45  □ 지역 : 글로벌 □ 출시 : '16.3월 □ 인치 : 40"/43"/50"/55...
#  46  □ 지역 : 글로벌 □ 출시 : '16.4월 □ 인치 : 32"/40"/43"/49...
#  47  □ 지역 : 글로벌 □ 출시 : '16.8월 □ 인치 : 22"/24"/28"/32...
#  48            □ 지역 : 글로벌 □ 출시 : '16.8월 □ 명칭 : S5E7570
#  49                           □ 지역 : 북미 □ 출시 : '16.12월
#  50                          □ 지역 : 글로벌 □ 출시 : '16.12월  ,
#                               0         1
#  0  < 국가별 등록 건수(2016년末 기준, 누적)>  (단위 : 件),
#     국가     한국     미국     유럽     중국    일본  기타국가
#  0  건수  27471  43806  16744  10242  6770  8813,
#                  0         1
#  0  < 연도별 특허등록 건수>  (단위 : 件),
#    특허등록  \n'16년\n  \n'15년\n  \n'14년\n  \n'13년\n  '12년  '11년  '10년  '09년
#  0   한국      3452      2984      3970      2762  2013  1610  1612  1485
#  1   미국      5518      5072      4952      4676  5081  4894  4551  3611,
#                   구분    2016년    2015년    2014년
#  0  온실가스(단위 : tCO2e)  6885300  6729419  6775019
#  1      에너지(단위 : TJ)   107740   111166   101386,
#                                                     0
#  0  ※ 대상 : 국내 제조사업장, 사옥, 당사 소유 건물, 임차 건물 등※ 온실가스 사...]
